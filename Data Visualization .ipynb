# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\FINAL YEAR PROJECT\dataset\FINAL_DATASET.csv")

# %%
sns.barplot(x=dataset.Sex , y=dataset.Age )
print('Comparison between Sex and Age attribute')
# Out:
# Comparison between Sex and Age attribute

# %%
sns.countplot(x=dataset.=['Female','Male'])
print("Compariosn between Male and Female individual")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12592\3158078127.py in <module>
# ----> 1 sns.countplot(x=Sex,rder=['Female','Male'])
#       2 print("Compariosn between Male and Female individual")
#
# NameError: name 'Sex' is not defined

# %%
sns.countplot(x=dataset.HeartDisease )
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %%
sns.countplot(x=dataset.ChestPainType)
# Out:
# <AxesSubplot:xlabel='ChestPainType', ylabel='count'>

# %%
sns.barplot(x="ChestPainType" , y = "Age", data=dataset)
# Out:
# <AxesSubplot:xlabel='ChestPainType', ylabel='Age'>

# %%
sns.catplot(x='Sex' , y='HeartDisease' , data=dataset , kind="box")

# %%
sns.catplot(x='Sex' , y='Age' ,hue='ChestPainType' , data=dataset , kind="box")

# %%
data=sns.FacetGrid(dataset, col="Sex" , row ="HeartDisease" , hue='HeartDisease')
data.map(plt.scatter,"Cholesterol","RestingBP")
plt.show()

# %%
data=sns.FacetGrid(dataset, col="FastingBS" , row ="HeartDisease")
data.map(plt.scatter,"Cholesterol","MaxHR")
plt.subplots_adjust(top=0.9)
plt.show()

# %%
sns.catplot(data=dataset , x="HeartDisease", y="Sex", kind="point")

# %%
sns.catplot(x='HeartDisease' , y='Age' , data=dataset , kind="point")
#strip”, “swarm”, “box”, “violin”, “boxen”, “point”, “bar”, or “count”.

# %%
#sns.catplot(x='Sex' , y='Age' ,hue='ChestPainType' , data=dataset , kind="box")

# %%
sns.catplot(y='HeartDisease' , x='ChestPainType' ,hue='HeartDisease', data=dataset , kind="point")

# %%
sns.catplot(x='HeartDisease' , y='RestingBP' , data=dataset , kind="violin")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12592\4131893810.py in <module>
# ----> 1 sns.jointplot("Age" ,"HearDisease"  ,data=dataset,color='red',hue='HeartDisease')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2228
#    2229     # Initialize the JointGrid object
# -> 2230     grid = JointGrid(
#    2231         data=data, x=x, y=y, hue=hue,
# ...

# %%
sns.catplot(x='HeartDisease' , y='Cholesterol' , data=dataset , kind="box")

# %%
sns.jointplot("RestingECG" ,"Cholesterol" ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("MaxHR" ,"Cholesterol"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(y='ST_Slope' , x='Oldpeak' , hue='HeartDisease' , data=dataset )

# %%
data=sns.FacetGrid(dataset, col="Sex" , row ="HeartDisease")
data.map(plt.scatter,"Age","MaxHR")
plt.subplots_adjust(top=0.9)
plt.show()

# %%
data=sns.FacetGrid(dataset, col="Sex" , row ="HeartDisease" , hue='HeartDisease')
data.map(plt.scatter,"Age","MaxHR")
plt.subplots_adjust(top=0.9)
plt.show()

# %%
sns.jointplot("Age" ,"MaxHR"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("MaxHR" ,"ExerciseAngina"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Oldpeak" ,"ST_Slope"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("ChestPainType" ,"ExerciseAngina"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("ST_Slope" ,"ExerciseAngina"  ,data=dataset,color='red',hue='HeartDisease')
# Out:
# C:\Users\sayuj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(y='ST_Slope' , x='Oldpeak' , hue='HeartDisease' , data=dataset )

# %%
sns.catplot(x='ExerciseAngina' , y='MaxHR' , hue='HeartDisease' , data=dataset , kind="box")
