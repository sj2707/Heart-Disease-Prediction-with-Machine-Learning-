# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as stats
from scipy.stats import pearsonr
dataset=pd.read_csv(r"C:\FINAL YEAR PROJECT\dataset\Heart.csv")

# %%
dataset.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
drop_0_age=dataset.index[dataset["Age"] ==0].tolist()

# %%
dataset=dataset.drop(dataset.index[drop_0_age])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
drop_0_bp=dataset.index[dataset["RestingBP"] ==0].tolist()

# %%
drop_0_bp
# Out:
# [449]

# %%
dataset=dataset.drop(dataset.index[drop_0_bp])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             917 non-null    int64
#  1   Sex             917 non-null    object
#  2   ChestPainType   917 non-null    object
#  3   RestingBP       917 non-null    int64
#  4   Cholesterol     917 non-null    int64
#  5   FastingBS       917 non-null    int64
#  6   RestingECG      917 non-null    object
#  7   MaxHR           917 non-null    int64
#  8   ExerciseAngina  917 non-null    object
#  9   Oldpeak         917 non-null    float64
#  10  ST_Slope        917 non-null    object
#  11  HeartDisease    917 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 93.1+ KB

# %%
drop_0_chol=dataset.index[dataset["Cholesterol"] ==0].tolist()

# %%
drop_0_chol
# Out:
# [293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384,
#  385,
#  386,
#  387,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  396,
#  397,
#  398,
#  399,
#  400,
#  401,
#  402,
#  403,
#  404,
#  405,
#  406,
#  407,
#  408,
#  409,
#  410,
#  411,
#  412,
#  413,
#  414,
#  415,
#  421,
#  423,
# ...

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()
plot_boxplot(dataset,"Cholesterol")

# %%
chol_0 = dataset['Cholesterol']
chol_0.replace(to_replace = 0, value = chol_0.mean(), inplace=True)

# %%
plot_boxplot(dataset,"Cholesterol")

# %%
drop_0_hr=dataset.index[dataset["MaxHR"] ==0].tolist()

# %%
drop_0_hr
# Out:
# []

# %%
#null value
data = pd.isnull(dataset["HeartDisease"])
   

dataset[data]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
plot_boxplot(dataset,"Age")

# %%
#bp
plot_boxplot(dataset,"RestingBP")

# %%
dataset.RestingBP.mean()
# Out:
# 132.54089422028352

# %%
upper_limit = dataset.RestingBP.mean() + 3*dataset.RestingBP.std()
upper_limit
# Out:
# 186.54014061847656

# %%
lower_limit = dataset.RestingBP.mean() - 3*dataset.RestingBP.std()
lower_limit
# Out:
# 78.54164782209048

# %%
dataset_bp_outlier=dataset[(dataset.RestingBP>upper_limit) | (dataset.RestingBP<lower_limit)]

# %%
dataset_bp_outlier
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190   241.000000          0     Normal
# 241   54   M           ASY        200   198.000000          0     Normal
# 365   64   F           ASY        200   199.016358          0     Normal
# 399   61   M           NAP        200   199.016358          1         ST
# 592   61   M           ASY        190   287.000000          1        LVH
# 732   56   F           ASY        200   288.000000          1        LVH
# 759   54   M           ATA        192   283.000000          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
dataset=dataset[(dataset.RestingBP<187)&(dataset.RestingBP>78)]
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 910 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             910 non-null    int64
#  1   Sex             910 non-null    object
#  2   ChestPainType   910 non-null    object
#  3   RestingBP       910 non-null    int64
#  4   Cholesterol     910 non-null    float64
#  5   FastingBS       910 non-null    int64
#  6   RestingECG      910 non-null    object
#  7   MaxHR           910 non-null    int64
#  8   ExerciseAngina  910 non-null    object
#  9   Oldpeak         910 non-null    float64
#  10  ST_Slope        910 non-null    object
#  11  HeartDisease    910 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.4+ KB

# %%
plot_boxplot(dataset,"RestingBP")

# %%
#cholesterol
plot_boxplot(dataset,"Cholesterol")

# %%
dataset.Cholesterol.mean()
# Out:
# 236.08215873548542

# %%
upper_limit = dataset.Cholesterol.mean() + 2*dataset.Cholesterol.std()
upper_limit
# Out:
# 348.7487147418336

# %%
lower_limit = dataset.Cholesterol.mean() - 2*dataset.Cholesterol.std()
lower_limit
# Out:
# 123.41560272913725

# %%
dataset_chol_outlier=dataset[(dataset.Cholesterol>upper_limit) | (dataset.Cholesterol<lower_limit)]

# %%
dataset_chol_outlier
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 28    53   F           ATA        113        468.0          0     Normal
# 30    53   M           NAP        145        518.0          0     Normal
# 58    54   M           ASY        150        365.0          0         ST
# 69    44   M           ASY        150        412.0          0     Normal
# 76    32   M           ASY        118        529.0          0     Normal
# 78    52   M           ATA        140        100.0          0     Normal
# 98    56   M           ASY        120         85.0          0     Normal
# 102   40   F           ASY        150        392.0          0     Normal
# 103   40   M           ASY        120        466.0          1     Normal
# 123   58   F           ATA        180        393.0          0     Normal
# 132   56   M           ASY        170        388.0          0         ST
# 149   54   M           ASY        130        603.0          1     Normal
# ...

# %%
dataset=dataset[(dataset.Cholesterol<upper_limit)&(dataset.Cholesterol>lower_limit)]
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 875 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             875 non-null    int64
#  1   Sex             875 non-null    object
#  2   ChestPainType   875 non-null    object
#  3   RestingBP       875 non-null    int64
#  4   Cholesterol     875 non-null    float64
#  5   FastingBS       875 non-null    int64
#  6   RestingECG      875 non-null    object
#  7   MaxHR           875 non-null    int64
#  8   ExerciseAngina  875 non-null    object
#  9   Oldpeak         875 non-null    float64
#  10  ST_Slope        875 non-null    object
#  11  HeartDisease    875 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 88.9+ KB

# %%
plot_boxplot(dataset,"Cholesterol")

# %%
#hr
plot_boxplot(dataset,"MaxHR")

# %%
dataset_hr_outlier=dataset[(dataset.MaxHR<65)]

# %%
dataset_hr_outlier
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 370   60   M           ASY        135   199.016358          0     Normal
# 390   51   M           ASY        140   199.016358          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 370     63              Y      0.5       Up             1
# 390     60              N      0.0     Flat             1

# %%
dataset=dataset[(dataset.MaxHR>65)]
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             873 non-null    int64
#  1   Sex             873 non-null    object
#  2   ChestPainType   873 non-null    object
#  3   RestingBP       873 non-null    int64
#  4   Cholesterol     873 non-null    float64
#  5   FastingBS       873 non-null    int64
#  6   RestingECG      873 non-null    object
#  7   MaxHR           873 non-null    int64
#  8   ExerciseAngina  873 non-null    object
#  9   Oldpeak         873 non-null    float64
#  10  ST_Slope        873 non-null    object
#  11  HeartDisease    873 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 88.7+ KB

# %%
plot_boxplot(dataset,"Oldpeak")

# %%
dataset=dataset[(dataset.Oldpeak<4)&(dataset.Oldpeak>-2)]
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 859 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             859 non-null    int64
#  1   Sex             859 non-null    object
#  2   ChestPainType   859 non-null    object
#  3   RestingBP       859 non-null    int64
#  4   Cholesterol     859 non-null    float64
#  5   FastingBS       859 non-null    int64
#  6   RestingECG      859 non-null    object
#  7   MaxHR           859 non-null    int64
#  8   ExerciseAngina  859 non-null    object
#  9   Oldpeak         859 non-null    float64
#  10  ST_Slope        859 non-null    object
#  11  HeartDisease    859 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 87.2+ KB

# %%
plot_boxplot(dataset,"Oldpeak")

# %%
dataset.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  859.000000  859.000000   859.000000  859.000000  859.000000
# mean    53.338766  131.706636   231.152153    0.232829  137.279395
# std      9.440429   17.045260    43.883473    0.422880   25.349146
# min     28.000000   80.000000   126.000000    0.000000   67.000000
# 25%     47.000000  120.000000   199.016358    0.000000  120.000000
# 50%     54.000000  130.000000   221.000000    0.000000  139.000000
# 75%     60.000000  140.000000   263.000000    0.000000  156.000000
# max     77.000000  185.000000   347.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  859.000000    859.000000
# mean     0.833295      0.541327
# std      0.970538      0.498579
# min     -1.500000      0.000000
# 25%      0.000000      0.000000
# 50%      0.500000      1.000000
# 75%      1.500000      1.000000
# max      3.800000      1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 859 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             859 non-null    int64
#  1   Sex             859 non-null    object
#  2   ChestPainType   859 non-null    object
#  3   RestingBP       859 non-null    int64
#  4   Cholesterol     859 non-null    float64
#  5   FastingBS       859 non-null    int64
#  6   RestingECG      859 non-null    object
#  7   MaxHR           859 non-null    int64
#  8   ExerciseAngina  859 non-null    object
#  9   Oldpeak         859 non-null    float64
#  10  ST_Slope        859 non-null    object
#  11  HeartDisease    859 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 87.2+ KB

# %%
dataset.to_csv(r"C:\FINAL YEAR PROJECT\dataset\new_data.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 859 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             859 non-null    int64
#  1   Sex             859 non-null    object
#  2   ChestPainType   859 non-null    object
#  3   RestingBP       859 non-null    int64
#  4   Cholesterol     859 non-null    float64
#  5   FastingBS       859 non-null    int64
#  6   RestingECG      859 non-null    object
#  7   MaxHR           859 non-null    int64
#  8   ExerciseAngina  859 non-null    object
#  9   Oldpeak         859 non-null    float64
#  10  ST_Slope        859 non-null    object
#  11  HeartDisease    859 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 87.2+ KB

# %%
data_corr=dataset.corr()

# %%
plt.figure(figsize=(10,9))
sns.heatmap(data_corr,cbar=True,annot=True)
plt.title("Heatmap ")
# Out:
# Text(0.5, 1.0, 'Heatmap ')
